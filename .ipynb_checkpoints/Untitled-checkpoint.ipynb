# %%
# %pip install pandas
# %pip install html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/kraakan/.local/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/lib/python3/dist-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/lib/python3/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting html
#   Using cached html-1.16.tar.gz (7.6 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-w9iwvs96/html_a947768f07094a05a1d8ee240bf02945/setup.py", line 12, in <module>
#           long_description = __doc__.decode('utf8'),
#       AttributeError: 'str' object has no attribute 'decode'. Did you mean: 'encode'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
# https://stackoverflow.com/questions/40399640/reading-csv-files-with-python-pandas-when-there-is-html-escaped-string-in-ther
import html
with open('BX-Books.csv', 'r', encoding='latin-1') as f, open('BX-Books-fixed.csv', 'w') as g:
    content = html.unescape(f.read())
    g.write(content)

# %%
users = pd.read_csv('BX-Users.csv', delimiter=';', encoding='latin-1')
books = pd.read_csv('BX-Books-fixed.csv', sep='(?<=\");(?=\")', engine='python', encoding='latin-1', on_bad_lines='warn', names=["ISBN","Book-Title","Book-Author","Year-Of-Publication","Publisher","Image-URL-S","Image-URL-M","Image-URL-L"])
# this regex should avoid interpreting semicolons as delimiter chars
ratings = pd.read_csv('BX-Book-Ratings.csv', encoding='latin-1', delimiter=';')

# %%
books
# Out:
#                 ISBN                                         Book-Title  \
# 0             "ISBN"                                       "Book-Title"
# 1       "0195153448"                              "Classical Mythology"
# 2       "0002005018"                                     "Clara Callan"
# 3       "0060973129"                             "Decision in Normandy"
# 4       "0374157065"  "Flu: The Story of the Great Influenza Pandemi...
# ...              ...                                                ...
# 271375  "0440400988"                       "There's a Bat in Bunk Five"
# 271376  "0525447644"                          "From One to One Hundred"
# 271377  "006008667X"  "Lily Dale : The True Story of the Town that T...
# 271378  "0192126040"                      "Republic (World's Classics)"
# 271379  "0767409752"  "A Guided Tour of Rene Descartes' Meditations ...
#
#                    Book-Author    Year-Of-Publication  \
# 0                "Book-Author"  "Year-Of-Publication"
# 1         "Mark P. O. Morford"                 "2002"
# 2       "Richard Bruce Wright"                 "2001"
# 3               "Carlo D'Este"                 "1991"
# 4           "Gina Bari Kolata"                 "1999"
# ...                        ...                    ...
# 271375        "Paula Danziger"                 "1988"
# 271376            "Teri Sloat"                 "1991"
# 271377      "Christine Wicker"                 "2004"
# 271378                 "Plato"                 "1996"
# 271379   "Christopher  Biffle"                 "2000"
#
#                                                 Publisher  \
# 0                                             "Publisher"
# 1                               "Oxford University Press"
# 2                                 "HarperFlamingo Canada"
# 3                                       "HarperPerennial"
# 4                                  "Farrar Straus Giroux"
# ...                                                   ...
# 271375                  "Random House Childrens Pub (Mm)"
# 271376                                     "Dutton Books"
# 271377                               "HarperSanFrancisco"
# 271378                          "Oxford University Press"
# 271379  "McGraw-Hill Humanities/Social Sciences/Langua...
#
#                                               Image-URL-S  \
# 0                                           "Image-URL-S"
# 1       "http://images.amazon.com/images/P/0195153448....
# 2       "http://images.amazon.com/images/P/0002005018....
# 3       "http://images.amazon.com/images/P/0060973129....
# 4       "http://images.amazon.com/images/P/0374157065....
# ...                                                   ...
# 271375  "http://images.amazon.com/images/P/0440400988....
# 271376  "http://images.amazon.com/images/P/0525447644....
# 271377  "http://images.amazon.com/images/P/006008667X....
# 271378  "http://images.amazon.com/images/P/0192126040....
# 271379  "http://images.amazon.com/images/P/0767409752....
#
#                                               Image-URL-M  \
# 0                                           "Image-URL-M"
# 1       "http://images.amazon.com/images/P/0195153448....
# 2       "http://images.amazon.com/images/P/0002005018....
# 3       "http://images.amazon.com/images/P/0060973129....
# 4       "http://images.amazon.com/images/P/0374157065....
# ...                                                   ...
# 271375  "http://images.amazon.com/images/P/0440400988....
# 271376  "http://images.amazon.com/images/P/0525447644....
# 271377  "http://images.amazon.com/images/P/006008667X....
# 271378  "http://images.amazon.com/images/P/0192126040....
# 271379  "http://images.amazon.com/images/P/0767409752....
#
#                                               Image-URL-L
# 0                                           "Image-URL-L"
# 1       "http://images.amazon.com/images/P/0195153448....
# 2       "http://images.amazon.com/images/P/0002005018....
# 3       "http://images.amazon.com/images/P/0060973129....
# 4       "http://images.amazon.com/images/P/0374157065....
# ...                                                   ...
# 271375  "http://images.amazon.com/images/P/0440400988....
# 271376  "http://images.amazon.com/images/P/0525447644....
# 271377  "http://images.amazon.com/images/P/006008667X....
# 271378  "http://images.amazon.com/images/P/0192126040....
# 271379  "http://images.amazon.com/images/P/0767409752....
#
# [271380 rows x 8 columns]

# %%
users.head()

# %%
print(users[0:1]['Location'])

# %%
type(users[0:1]['Location'][0])

# %%
ratings.head()

# %%
books.info()

# %%
type(books['ISBN'][1])

# %%
users.info()

# %%
ratings.info()

# %% [markdown]
# The data looks pretty good.
# I want to add fields for number of reviews to the users and books.

# %%
# EDA what now?
import seaborn as sn
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

sn.histplot(data=ratings, x="User-ID", stat='frequency')
plt.show()

# %% [markdown]
# This graph gives an idea of the average number of ratings per user, but it's misleading because it doesn't show that over half the users have no ratings.

# %%
print('Number of users with reviews: ', len(pd.unique(ratings['User-ID'])), 'out of', len(users), 'users')
print('Number of books reviewed: ', len(pd.unique(ratings['ISBN'])), 'out of', len(books), 'books (???)')
print("This can't be right! Either there is a problem with the ISBNs in the ratings file, or some of the books aren't listed.")

# %%
ratings.head()

# %%
ratings.loc[ratings['ISBN'] == '0192126040']

# %%
mean_ratings = ratings.groupby(['ISBN'], sort=False, as_index=False).mean()

# %%
mean_ratings

# %%
rating_counts = ratings.groupby(['ISBN'], sort=False, as_index=False).count()

# %%
rating_counts

# %%
books_with_ratings = mean_ratings.merge(rating_counts, on='ISBN', suffixes=('-Mean', '-Count')).drop(['User-ID-Mean', 'User-ID-Count'], axis=1)

# %%
books_with_ratings.sort_values(by='Book-Rating-Mean', ascending=False)
# Out:
#               ISBN  Book-Rating-Mean  Book-Rating-Count
# 155265  3455019080              10.0                  1
# 243967  8806156225              10.0                  1
# 104467  0875884520              10.0                  1
# 176813  0345462831              10.0                  1
# 104466  087196676X              10.0                  1
# ...            ...               ...                ...
# 217468  9500720434               0.0                  1
# 217469  9505114354               0.0                  1
# 87339   0824511492               0.0                  1
# 87338   0824510445               0.0                  2
# 170278  0684195860               0.0                  1
#
# [340556 rows x 3 columns]

# %% [markdown]
# I'd like to list the most popular books, and since the highest rated ones all have just one rating, I'm going to set a limit of, let's say, 50 reveiews.

# %%
books_with_ratings[books_with_ratings['Book-Rating-Count']>50].sort_values(by='Book-Rating-Mean', ascending=False)
# Out:
#              ISBN  Book-Rating-Mean  Book-Rating-Count
# 13715  1844262553          7.962963                 54
# 529    0439064864          6.611765                170
# 9496   0439139597          6.541237                194
# 9495   0439136350          6.467005                197
# 9542   0590353403          6.363095                168
# ...           ...               ...                ...
# 452    0971880107          1.019584               2502
# 9508   0446356832          1.011905                 84
# 5830   0425173534          0.970149                 67
# 44645  1401088945          0.735294                 68
# 24602  0345345738          0.549020                 51
#
# [2125 rows x 3 columns]

# %%
books.loc[books['ISBN'].str.contains('0439064864', case=False)]

# %%
books.loc[books['Book-Author'].str.contains('Immanuel Kant', case=False)]

# %%
books_with_ratings.iloc[1]['ISBN']
# Out:
# '0155061224'

# %%
books_with_ratings[books_with_ratings['Book-Rating-Count']>50].sort_values(by='Book-Rating-Mean', ascending=False)['ISBN']

# %%
def get_book(isbn, df = books):
    return df.loc[df['ISBN'].str.contains(isbn, case=False)]

# %%
get_book('0192126040')
# Out:
#                 ISBN                     Book-Title Book-Author  \
# 271378  "0192126040"  "Republic (World's Classics)"     "Plato"
#
#        Year-Of-Publication                  Publisher  \
# 271378              "1996"  "Oxford University Press"
#
#                                               Image-URL-S  \
# 271378  "http://images.amazon.com/images/P/0192126040....
#
#                                               Image-URL-M  \
# 271378  "http://images.amazon.com/images/P/0192126040....
#
#                                               Image-URL-L
# 271378  "http://images.amazon.com/images/P/0192126040....

# %%
def recommend_books(books_read, titles=books, reviews=books_with_ratings, mode='popularity', n=10, min_ratings=50):
    titles_list = pd.DataFrame()
    reviews_list = pd.DataFrame()
    popular = reviews[reviews['Book-Rating-Count']>min_ratings].sort_values(by='Book-Rating-Mean', ascending=False)
    i = 0
    while len(titles_list.index) < n:
        # get most popular isbns
        isbn = popular.iloc[i]['ISBN']
        print(titles_list)
        if isbn not in books_read['ISBN']:
            title = get_book(isbn)
            pd.concat([titles_list, title]) # HÄR ÄR FEL!
            #titles_list.append(title)
            #review = get_book(isbn, df = reviews)
            #reviews_list.append(review)
        i+=1
    # Make dataframe from lists
    #titles_df = pd.DataFrame([titles_list])
    #reviews_df = pd.DataFrame(reviews_list)
    
    #return_df = titles_df.merge(reviews_df, on='ISBN')
    return titles_df

# %%
Kant = books.loc[books['Book-Author'].str.contains('Immanuel Kant', case=False)] 
recommend_books(Kant)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12195/1361570743.py in <module>
#       1 Kant = books.loc[books['Book-Author'].str.contains('Immanuel Kant', case=False)]
# ----> 2 recommend_books(Kant)
#
# /tmp/ipykernel_12195/1888886278.py in recommend_books(books_read, titles, reviews, mode, n, min_ratings)
#       9         print(titles_list)
#      10         if isbn not in books_read['ISBN']:
# ---> 11             title = get_book(isbn)
#      12             pd.concat([titles_list, title])
#      13             #titles_list.append(title)
#
# /tmp/ipykernel_12195/4283465003.py in get_book(isbn, df)
#       1 def get_book(isbn, df = books):
# ----> 2     return df.loc[df['ISBN'].str.contains(isbn, case=False)]
#
# ~/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     127                 )
#     128                 raise TypeError(msg)
# --> 129             return func(self, *args, **kwargs)
#     130
#     131         wrapper.__name__ = func_name
#
# ~/.local/lib/python3.10/site-packages/pandas/core/strings/accessor.py in contains(self, pat, case, flags, na, regex)
#    1258             )
#    1259
# -> 1260         result = self._data.array._str_contains(pat, case, flags, na, regex)
#    1261         return self._wrap_result(result, fill_value=na, returns_string=False)
#    1262
#
# ~/.local/lib/python3.10/site-packages/pandas/core/strings/object_array.py in _str_contains(self, pat, case, flags, na, regex)
#     129                 upper_pat = pat.upper()
#     130                 f = lambda x: upper_pat in x.upper()
# --> 131         return self._str_map(f, na, dtype=np.dtype("bool"))
#     132
#     133     def _str_startswith(self, pat, na=None):
#
# ~/.local/lib/python3.10/site-packages/pandas/core/strings/object_array.py in _str_map(self, f, na_value, dtype, convert)
#      69         map_convert = convert and not np.all(mask)
#      70         try:
# ---> 71             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      72         except (TypeError, AttributeError) as err:
#      73             # Reraise the exception if callable `f` got wrong number of args.
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer_mask()
#
# ~/.local/lib/python3.10/site-packages/pandas/core/strings/object_array.py in <lambda>(x)
#     122             pat = re.compile(pat, flags=flags)
#     123
# --> 124             f = lambda x: pat.search(x) is not None
#     125         else:
#     126             if case:
#
# KeyboardInterrupt:
